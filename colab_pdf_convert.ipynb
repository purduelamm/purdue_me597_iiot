# %%
# run shell command to enable texlive for PDF converting directy from jupyter notebook
# It will take a couple of minutes.
# !sudo apt-get install texlive-xetex texlive-fonts-recommended texlive-plain-generic

# %%
# Change the file path!
# !jupyter nbconvert --to pdf '/content/drive/MyDrive/Copy_of_PL0_Colab1.ipynb'
